# %% [markdown]
# ## Instala o Pacote

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# ## Importa Bibliotecas

# %%
import google.generativeai as genai #Faz conexão com as llm do google
#from google.colab import userdata #Faz a configuração da chave

#Pacotes de Formatação
import textwrap
from IPython.display import Markdown
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %% [markdown]
# ## Configuração de Chave
# 1. Vá em https://aistudio.google.com/api-keys, crie a chave e copie.
# 2. No colab, crie uma variável de ambiente clicando no símbolo de "🔑" na esquerda do seu monitor. Cole a chave em 'value' e o nome deve ser igual ao que vc colocar no lugar de GEMINI_API_KEY entre aspas no código abaixo.

# %%
#GOOGLE_API_KEY = userdata.get("GEMINI_API_KEY")

genai.configure(api_key=GOOGLE_API_KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4135176433.py in <cell line: 0>()
#       1 #GOOGLE_API_KEY = userdata.get("GEMINI_API_KEY")
#       2
# ----> 3 genai.configure(api_key=GOOGLE_API_KEY)
#
# NameError: name 'GOOGLE_API_KEY' is not defined

# %% [markdown]
# ## Escolher Modelo
# Digite o nome do modelo entre as aspas.

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
#Execute esse bloco APENAS se quiser ver uma lista de modelos.
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)

# %% [markdown]
# ## Enviar Pergunta
# Coloque a pergunta que você quer fazer entre as aspas.

# %%
# %%time
response = model.generate_content(
    "Explique passo a passo, com 3 exemplos, a diferença entre classe e objeto em pyhton, com a síntaxe de cada um e de maniera didática."
    )
# Out:
# CPU times: user 140 ms, sys: 17.9 ms, total: 158 ms
# Wall time: 21.9 s

# %% [markdown]
# ## Configurações para Formatação
# A fução abaixo vai formatar melhor a respota, para deixar mais "limpa" visualmente.

# %%
def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %% [markdown]
# Exibir Resposta

# %%
to_markdown(response.text)
#Teste print(response.txt) para ver a diferença sem a formatação.
# Out:
# > Com certeza! Vamos entender a diferença fundamental entre Classes e Objetos em Python de uma forma bem didática, usando uma analogia e depois partindo para exemplos práticos.
# >
# > ---
# >
# > ### **A Grande Analogia: A Forma de Bolo vs. O Bolo Assado**
# >
# > Imagine que você quer fazer vários bolos.
# >
# > *   **A Forma de Bolo (A CLASSE):**
# >     *   É o **molde**, o **projeto**, a **receita**.
# >     *   Ela define as características que *todos* os bolos feitos com ela terão (por exemplo, tamanho, formato redondo).
# >     *   Ela define o que você pode *fazer* com ela (por exemplo, colocar massa, assar).
# >     *   **Mas a forma, por si só, não é um bolo que você possa comer.** Ela é apenas a *especificação* de como um bolo deve ser.
# >
# > *   **O Bolo Assado (O OBJETO):**
# >     *   É o **bolo real**, concreto, que saiu da forma.
# ...

# %% [markdown]
# !pip install google-genai
# from google.colab import userdata
# from google.genai import Client
#
# api_key = userdata.get("GEMINI_API_KEY")
# client = Client(api_key=api_key)
#
# response = client.models.generate_content(
#     model = "gemini-2.0-flash",
#     contents = "Explique passo a passo e dê exemplos do que é uma classe e um objeto em python."
# )
#
# print(response.text)
